# %%
import pandas as pd 
import numpy as np
import os
import pickle as pkl

# %%
mode = 'train' # or 'test

data_path = 'optogpt_data/' + mode 

data_names = os.listdir(data_path)

df_list = []

for file in data_names:
    df_ = pd.read_csv(os.path.join(data_path, file))
    df_list.append(df_)
    
df = pd.concat(df_list, ignore_index=True)

# %%
df
# Out:
#          Unnamed: 0                                          structure  \
# 0                 0  ['Ta2O5_300', 'AlN_320', 'Ta2O5_340', 'HfO2_40...
# 1                 1  ['MgO_270', 'TiO2_40', 'ZnO_190', 'HfO2_380', ...
# 2                 2  ['Ge_290', 'Si3N4_10', 'Al_240', 'Si3N4_70', '...
# 3                 3  ['Ta2O5_240', 'ITO_380', 'SiO2_280', 'ZnO_480'...
# 4                 4  ['MgF2_180', 'MgO_260', 'Al_80', 'TiN_450', 'T...
# ...             ...                                                ...
# 1999995      999995  ['SiO2_250', 'TiO2_230', 'SiO2_280', 'Al2O3_46...
# 1999996      999996  ['ZnO_390', 'Ta2O5_230', 'ZnSe_280', 'SiO2_40'...
# 1999997      999997  ['HfO2_470', 'MgF2_380', 'SiO2_180', 'MgO_190'...
# 1999998      999998  ['ZnS_30', 'Ta2O5_180', 'Si_240', 'TiO2_130', ...
# 1999999      999999  ['Si3N4_230', 'Al2O3_300', 'AlN_380', 'MgO_190...
#
#          num_layers   R_400nm   R_410nm   R_420nm   R_430nm   R_440nm  \
# 0                17  0.143154  0.270409  0.068258  0.203140  0.207752
# 1                17  0.136712  0.179132  0.094669  0.100362  0.221289
# 2                17  0.468274  0.466390  0.464940  0.463112  0.461049
# 3                19  0.134639  0.224011  0.160732  0.215428  0.171378
# 4                19  0.651219  0.659221  0.705439  0.759390  0.802410
# ...             ...       ...       ...       ...       ...       ...
# 1999995           9  0.248247  0.308116  0.134344  0.107044  0.178223
# 1999996          20  0.212542  0.166814  0.059436  0.129534  0.239894
# 1999997          18  0.062330  0.057941  0.175788  0.340479  0.208117
# 1999998          16  0.078694  0.102208  0.151683  0.208780  0.260142
# 1999999          18  0.223563  0.360772  0.246068  0.019224  0.070039
#
#           R_450nm   R_460nm  ...      T_1010nm      T_1020nm      T_1030nm  \
# 0        0.133908  0.256749  ...  7.279138e-20  6.708738e-20  4.977434e-20
# 1        0.300830  0.291660  ...  2.466956e-01  2.217513e-01  2.162272e-01
# 2        0.458892  0.456624  ...  5.828044e-23  9.855431e-23  1.372599e-22
# 3        0.064131  0.113954  ...  1.791174e-01  2.166785e-01  2.527115e-01
# 4        0.831643  0.849628  ...  3.709293e-18  3.902026e-18  3.491132e-18
# ...           ...       ...  ...           ...           ...           ...
# 1999995  0.289747  0.185345  ...  7.265530e-01  7.134139e-01  6.981519e-01
# 1999996  0.211835  0.077812  ...  2.165693e-19  3.526536e-19  5.911565e-19
# 1999997  0.308702  0.236718  ...  1.499599e-01  1.784428e-01  1.989469e-01
# 1999998  0.295036  0.311392  ...  3.359812e-21  3.639918e-21  4.014346e-21
# 1999999  0.222433  0.200406  ...  1.674699e-01  1.698070e-01  1.845447e-01
#
#              T_1040nm      T_1050nm      T_1060nm      T_1070nm      T_1080nm  \
# 0        3.349879e-20  2.357321e-20  1.845059e-20  1.634083e-20  1.645585e-20
# 1        2.241115e-01  2.363959e-01  2.409754e-01  2.310539e-01  2.122547e-01
# 2        1.465879e-22  1.327228e-22  1.149973e-22  9.994108e-23  8.733339e-23
# 3        2.603744e-01  2.430273e-01  2.243570e-01  2.154357e-01  2.151012e-01
# 4        2.958163e-18  2.665547e-18  2.660998e-18  2.863903e-18  3.030304e-18
# ...               ...           ...           ...           ...           ...
# 1999995  6.820254e-01  6.665148e-01  6.529206e-01  6.421852e-01  6.347691e-01
# 1999996  9.458620e-19  1.289738e-18  1.388152e-18  1.214964e-18  9.433717e-19
# 1999997  2.081872e-01  2.118915e-01  2.082258e-01  1.912477e-01  1.665002e-01
# 1999998  4.422215e-21  4.775591e-21  4.983909e-21  4.991032e-21  4.789933e-21
# 1999999  2.087810e-01  2.312235e-01  2.395830e-01  2.362823e-01  2.329998e-01
#
#              T_1090nm      T_1100nm
# 0        1.893093e-20  2.501610e-20
# 1        1.949739e-01  1.856023e-01
# 2        7.615815e-23  6.604243e-23
# 3        2.178291e-01  2.189599e-01
# 4        2.821330e-18  2.301221e-18
# ...               ...           ...
# 1999995  6.306720e-01  6.294758e-01
# 1999996  6.990779e-19  5.163660e-19
# 1999997  1.461210e-01  1.359751e-01
# 1999998  4.425239e-21  3.967554e-21
# 1999999  2.346766e-01  2.354661e-01
#
# [2000000 rows x 145 columns]

# %%
import ast

spec_index = ['R_'+str(i)+'nm' for i in range(400, 1110, 10)] + ['T_'+str(i)+'nm' for i in range(400, 1110, 10)]

spec = df[spec_index].values

structure = list(df['structure'].apply(ast.literal_eval))

# %%
with open('dataset/Structure_'+mode+'.pkl', 'wb') as files:
    pkl.dump(structure, files)
    
with open('dataset/Spectrum_'+mode+'.pkl', 'wb') as files:
    pkl.dump(spec, files)
